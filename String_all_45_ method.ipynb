# %% [markdown]
# # 1.capitalize()

# %% [markdown]
# # 2.Upper()

# %%
name = input("enter your name :")
name = name.upper()
print(f"hi {name}")
# Out:
# enter your name : ashish
# hi ASHISH

# %% [markdown]
# # 3.lower()

# %%
name = input("enter your name :")
name = name.upper()
print(f"hi {name}")
# Out:
# enter your name : ashish
# hi ASHISH

# %% [markdown]
# # 3.title()

# %%
name = input("enter your name :")
print(f" hi {name.title()}")
# Out:
# enter your name : ashish chauhan
#  hi Ashish Chauhan

# %% [markdown]
# # 4.swapcase()

# %%
name = input("enter your name :")
print(f"hi {name.swapcase()}")
# Out:
# enter your name : ASGsghd
# hi asgSGHD

# %% [markdown]
# # 5.casefold()

# %%
name = input("enter your name : ")
name = name.casefold()
print(name)

name1 = "ashish"
name2 = "ASHISH"
print(name1.casefold() == name2.casefold())
# Out:
# enter your name :  ashish
# ashish
# True

# %% [markdown]
# # 6.strip()

# %%
name = "$$ashish chauhan$$"
print(name.strip("$"))
# Out:
# ashish chauhan

# %%
name = input("enter your name :")
print(f" hi {name.strip()}")
# Out:
# enter your name : @@@ashish@@@
#  hi @@@ashish@@@

# %% [markdown]
# # 7.center()

# %%
name = "rahul"
print(name.center(30,'$'))
# Out:
# $$$$$$$$$$$$rahul$$$$$$$$$$$$$

# %% [markdown]
# # 8.count()

# %%
name = "ashish chauhan"
print(name.count("a"))
# Out:
# 3

# %% [markdown]
# # 9.encode

# %%
name = input("enter your name :")
name = name.encode("utf 8")
print(name)
# Out:
# enter your name : system
# b'system'

# %% [markdown]
# # 10.endswith

# %%
num = input("enter your number :")
num = num.endswith("123456789")
print(num)
# Out:
# enter your number : 123456789
# True

# %% [markdown]
# # 11.expandtabs()

# %%
data = input("enter your data : ")

data = data.replace("\\t", "\t")

data = data.expandtabs(6)

print(data)
# Out:
# enter your data :  dfghj\tyu
# dfghj yu

# %% [markdown]
# # 12.find()

# %%
data = input("enter your data")
data = data.find("h",3)
print(data)
# Out:
# enter your data ashish
# 5

# %% [markdown]
# # 12.format()

# %%
name = input("enter your name :")
age = input("enter your age :")
print("my name is {} and my age {}".format(name,age))
# Out:
# enter your name : Ashish
# enter your age : 21
# my name is Ashish and my age 21

# %% [markdown]
# # 13.format map()

# %%
name = input("enter your name :")
age = input("enter your age :")

data = {
    "name": name,
    "age" : age,
}

print("my name is {name} and my age {age}".format_map(data))
# Out:
# enter your name : aman
# enter your age : 55
# my name is aman and my age 55

# %% [markdown]
# # 14.index()

# %%
data = input("enter your data :")
data = data.index("f")
print(data)
# Out:
# enter your data : faruki
# 0

# %% [markdown]
# # 15.isalnum()

# %%
name = input("enter ypur text :")
print(name.isalnum())
# Out:
# enter ypur text : gaurav
# True

# %% [markdown]
# # 16.isalpha()

# %%
name = input("enter your data :")
print(name.isalpha())
# Out:
# enter your data : ashish
# True

# %% [markdown]
# # 17.isascii()

# %%
name = input("enter your data :")
print(name.isascii())
# Out:
# enter your data : dfghj
# True

# %% [markdown]
# # 18.isdecimal()

# %%
name = input("enter your data :")
print(name.isdecimal())
# Out:
# enter your data : 3456
# True

# %% [markdown]
# # 19.isdigit()

# %%
data = input("enter your data :")
print(data.isdigit())
# Out:
# enter your data : 23456
# True

# %% [markdown]
# # 20.isidentifire()

# %%
name = input("enter your data :")
print(name.isidentifier())
# Out:
# enter your data : sdfghjkl
# True

# %% [markdown]
# # 21.islower()

# %%
name = input("enter your data :")
print(name.islower())
# Out:
# enter your data : ashish
# True

# %% [markdown]
# # 22.isnumeric()

# %%
name = input("enter your data :")
print(name.isnumeric())
# Out:
# enter your data : 2345678
# True

# %% [markdown]
# # 23.isprintable()

# %%
name = input("enter your data :")
print(name.isprintable())
# Out:
# enter your data : 234567
# True

# %% [markdown]
# # 24.isspace()

# %%
name = input(" enter your data : ")
print(name.isspace())
# Out:
#  enter your data :  ashish chauhan
# False

# %% [markdown]
# # 25.istitle()

# %%
name = input("enter your data :")
print(name.istitle())
# Out:
# enter your data : Ashish Chauhan
# True

# %% [markdown]
# # 26.isupper()

# %%
data = input("enter your data :")
print(data.isupper())
# Out:
# enter your data : ASHISH
# True

# %% [markdown]
# # 27.join()

# %%
name = input("enter your data :")
print("|".join(name))
# Out:
# enter your data : ashish
# a|s|h|i|s|h

# %% [markdown]
# # 28.ljust()

# %%
name = input("enter your data :")
print(name.ljust(10,"*"))
# Out:
# enter your data : Ashish
# Ashish****

# %% [markdown]
# # 29.maketrans()

# %%
name = "ashish cyckle banana"
table = str.maketrans("abc","123")
print(name.translate(table))
# Out:
# 1shish 3y3kle 21n1n1

# %% [markdown]
# # 30.partiton()

# %%
name = "ashish-chauhan"
name = name.partition("-")
print(name)
# Out:
# ('ashish', '-', 'chauhan')

# %% [markdown]
# # 31.replace()

# %%
name = input("enter your name :")
name = name.replace("ashish","gaurav")
print(name)
# Out:
# enter your name : gaurav kumar
# gaurav kumar

# %% [markdown]
# # 32.rfind()

# %%
text = "python is easy python"
result = text.rfind("python")
print(result)
# Out:
# 15

# %% [markdown]
# # 33.rindex()

# %%
name = "banana"

result = name.rindex("a")

print(result)
# Out:
# 5

# %% [markdown]
# # 34.rjust()

# %%
name = input("enter your name :")
name = name.rjust(12,"#")
print(name)
# Out:
# enter your name : aman
# ########aman

# %% [markdown]
# # 35.rpartition()

# %%
name = input("enter your name :")
name = name.rpartition("-")
print(name)
# Out:
# enter your name : ashish chauhan
# ('', '', 'ashish chauhan')

# %% [markdown]
# # 36.rsplit()

# %%
name = input("enter your name :")
name = name.rsplit("$")
print(name)
# Out:
# enter your name : ashish-vikas
# ['ashish-vikas']

# %% [markdown]
# # 37.splitlines()

# %%
data = input("enter your name :")
data = data.splitlines("true")
print(data)
# Out:
# enter your name : ashish\nchauhan
# ['ashish\\nchauhan']

# %% [markdown]
# # 38.startswith()

# %% [markdown]
# # 39.strip()

# %%
name = input("enter your name")
name = name.strip("ccc")
print(name)
# Out:
# enter your name cccasshishccc
# asshish

# %% [markdown]
# # 40.title()

# %%
name = input("enter your name")
name = name.title()
print(name)
# Out:
# enter your name ashish chauhan
# Ashish Chauhan

# %% [markdown]
# # 41.translate()

# %%
table = str.maketrans("","","aeiou")
name = "python programing"
name = name.translate(table)
print(name)
# Out:
# pythn prgrmng

# %% [markdown]
# # 42.upper()

# %%
name = "ashish chauhan"
name = name.upper()
print(name)
# Out:
# ASHISH CHAUHAN

# %% [markdown]
# # 43.zfill()

# %%
name = "ashish"
print(name)
# Out:
# ashish
