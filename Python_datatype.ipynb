# %%
#Integer Detetype

marks = 90
print(type(marks))
# Out:
# <class 'int'>

# %%
#Float Datatype

marks = 90.79
print(type(marks))
# Out:
# <class 'float'>

# %%
#String Datatype

marks = "gaurav"
marks = "70"
marks = "56.78"
print(type(marks))
# Out:
# <class 'str'>

# %%
print("78" + "67" + "78" + "90")
# Out:
# 78677890

# %%
print(78+90)
# Out:
# 168

# %%
#Boolian Datatype 

value = True
value = False
print(type(value))
print(66==66)
print(55>77)
# Out:
# <class 'bool'>
# True
# False

# %%
#List Datatype

a = 45
b = 67
c = 90
d = 65
e = 89
f = 67

marks = [45,67,90,65,89,67]
print(marks[0])
print(marks[1])
print(marks[2])
print(marks[3])
print(marks[4])
print(marks[5])
print(type(marks))
# Out:
# 45
# 67
# 90
# 65
# 89
# 67
# <class 'list'>

# %%
#Tuple Datatype

a = 45
b = 67
c = 90
d = 65
e = 89

marks = (45,67,90,65,45)
print(marks[0])
print(marks[1])
print(marks[2])
print(marks[3])
print(marks[4])
print(type(marks))
# Out:
# 45
# 67
# 90
# 65
# 45
# <class 'tuple'>

# %%
var = 1,2,3,4,5,6,7
print(var)
print(type(var))
# Out:
# (1, 2, 3, 4, 5, 6, 7)
# <class 'tuple'>

# %%
#Set Datatype

marks = {45,34,56,67,34}
print(marks)
print(type(marks))
# Out:
# {56, 34, 67, 45}
# <class 'set'>

# %%
#Dictinary Datatype

dict1 = {"ashish":67,"aman":78,"mukesh":60}
print(type(dict1))
dict1["mukesh"]
# Out:
# <class 'dict'>
# 60

# %%
#None Datatype

x = None
print(x)
print(type(x))
x = 90
print(x)
# Out:
# None
# <class 'NoneType'>
# 90
