# %%
#Arithmatic Operater

print(45/2)
print(20//2)
# Out:
# 22.5
# 10

# %%
print(2*7)
print(6**3)
# Out:
# 14
# 216

# %%
print(3%4)
print(20%2)
# Out:
# 3
# 0

# %%
marks = 87
print(marks)
print(marks + 3)
marks = marks + 3
# Out:
# 87
# 90

# %%
    #Assignment Operater

marks += 5
print(marks)
# Out:
# 83

# %%
marks = 78
print(marks)
print(marks*5)
# Out:
# 78
# 390

# %%
marks *= 3
print(marks)
# Out:
# 228

# %%
marks = 90
print(marks)
print(marks - 5)
# Out:
# 90
# 85

# %%
marks -= 7
print(marks)
# Out:
# 76

# %%
x = 5
print(x)
# Out:
# 5

# %%
#Comparison Operater

a = 8
b = 8
print(a == b)
print(b > b)
print(b < b)
print(b <= b)
print(b >= b)
print(b != b)
# Out:
# True
# False
# False
# True
# True
# False

# %%
#Logical Operater

print(66 == 66 and 55 == 55)
print(66 == 66 and 55 == 56)
print(66 == 66 or 55 == 56)
print(66 == 66 or 55 == 55)
print(66 == 67 or 55 == 65)
print(66 == 67 or 55 == 65)
print(not(66 == 66 or 55 == 55))
print(not(67 == 66 or 55 == 58))
print(not(True))
# Out:
# True
# False
# True
# True
# False
# False
# False
# True
# False

# %%
#Identity Operater

a = 7
b = 7
c = 7
print(id(a))
print(id(b))
print(id(c))
print(a is b)
print(a == b)
# Out:
# 140721995490408
# 140721995490408
# 140721995490408
# True
# True

# %%
list1 = [1,2,3,4]
list2 = [1,2,3,4]
list3 = [1,2,3,4]
print(list1 == list2 == list3)
print(list1 is list2 is list3)
print(id(list1))
print(id(list2))
print(id(list3))
# Out:
# True
# False
# 1802557787072
# 1802558011520
# 1802558056576

# %%
#Membership Operater

string = "This is python class"

list1 = [13,45,55]

print("python" in string)
print("java" not in string)
print("java" in string)
print(13 in list1)
# Out:
# True
# True
# False
# True

# %%
#Walrus Operater

print(y := 5)
# Out:
# 5

# %%
#Bitwise and Operater

print(31 & 54)
# Out:
# 22

# %%
print(45 | 56)
# Out:
# 61

# %%
name = "ASHISH"
print(name[0])
print(name[1])
print(name[2])
print(name[3])
print(name[4])
print(name[5])
# Out:
# A
# S
# H
# I
# S
# H

# %%
name = "ASHISH"
print(name[-1])
print(name[-2])
print(name[-3])
print(name[-4])
print(name[-5])
print(name[-6])
# Out:
# H
# S
# I
# H
# S
# A

# %%
name = "ASHISH"
print(name[-1:2:-1])
# Out:
# HSI

# %%
name = "KANHAIYA"
print(name[1:6:1])
# Out:
# ANHAI

# %%
name = "MUKESH"
print(name[-2:-4:-1
# Out:
# SE

# %% [markdown]
# ###
