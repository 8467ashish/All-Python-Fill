# %% [markdown]
# # 1.Take a number from the user and check whether it is positive or negative.

# %%
number = int(input("enter your number :"))
if number > 0:
    print("enter your posetive number")
else:
   print("enter your negativ number")
# Out:
# enter your number : 67
# enter your posetive number

# %% [markdown]
# # 2.Take a number and check whether it is even or odd.

# %%
number = int(input("enter your number :"))
if number > 0:
    print("enter your even number :")
else:
    print("enter your odd number")
# Out:
# enter your number : 137
# enter your even number :

# %% [markdown]
# # 3.Take a number and check whether it is greater than 10 or not.

# %%
number = int(input("enter your number"))
if number > 10:
    print("enter your greter  number")
else:
    print("enter your less number")
# Out:
# enter your number 45
# enter your greter  number

# %% [markdown]
# # 4.Take age as input and check whether the person is eligible to vote.

# %%
age = int(input("enter your age"))
if age > 22:
    print("you are eligible to vote")
else:
    print("you are not eligible vote")
# Out:
# enter your age 22
# you are not eligible vote

# %% [markdown]
# # 5.Take marks as input and check whether the student passed or failed (passing marks = 40)

# %%
marks = int(input("enter your marks"))
if marks > 40:
    print("you are passed")
else:
    print("you are faild")
# Out:
# enter your marks 41
# you are passed

# %% [markdown]
# # 6.Take two numbers and print which one is greater.

# %%
num1 = int(input("enter your number"))
num2 = int(input("enter your number"))
if num1 > num2:
    print(num1, "is greater")
else:
    print(num2, "is greater")
# Out:
# enter your number 45
# enter your number 56
# 56 is greater

# %% [markdown]
# # 7.Take a number and check whether it is divisible by 5

# %%
number = int(input("enter your numbe"))
if number % 5 == 0:
    print("It is devisible")
else:
    print("It is not divisible")
# Out:
# enter your numbe 45
# It is devisible

# %% [markdown]
# # 8.Take a number and check whether it is zero or not.

# %%
number = int(input("enter your number"))
if number == 0:
    print("this number is zero")
else:
    print("this number is not zero")
# Out:
# enter your number 1
# this number is not zero

# %% [markdown]
# # 9.Take three numbers and find the largest among them.

# %%
num1 = int(input("enter your number"))
num2 = int(input("enter your number"))
num3 = int(input("enter your number"))
if num1 >= num2 and num1  >= num3:
    print("largest  number is:",num1)
elif num2 >= num1 and num2 >= num3:
    print("largest number is:",num2)
else:
    print("largest number is:",num3)
# Out:
# enter your number 45
# enter your number 48
# enter your number 65
# largest number is: 65

# %% [markdown]
# # 10.Take a year as input and check whether it is a leap year.

# %%
year = int(input("Enter a year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter a year:  2025
# Not a Leap Year

# %% [markdown]
# # 11.Take marks and assign grade:
#  90 and above → A  75 to 89 → B  50 to 74 → C  Below 50 → Fail

# %%
marks = int(input("Enter your marks: "))

if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 50:
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter your marks:  94
# Grade A

# %% [markdown]
# # 12.Take a character as input and check whether it is a vowel or consonant.

# %%
ch = input("Enter a character: ")

if ch in "aeiouAEIOU":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter a character:  I
# Vowel

# %% [markdown]
# # 13.Take two numbers and find the smallest among them.

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

if num1 < num2:
    print("Smallest number is:", num1)
else:
    print("Smallest number is:", num2)
# Out:
# Enter first number:  54
# Enter second number:  67
# Smallest number is: 54

# %% [markdown]
# # 14.Take a number and check whether it is a multiple of both 3 and 7.

# %%
number = int(input("Enter a number: "))

if number % 3 == 0 and number % 7 == 0:
    print("The number is a multiple of both 3 and 7")
else:
    print("The number is not a multiple of both 3 and 7")
# Out:
# Enter a number:  35
# The number is not a multiple of both 3 and 7

# %% [markdown]
# # 15.Create a simple calculator:
# . Take two numbers and an operator (+, -, *, /) . Perform operation based on user input.

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operator = input("Enter operator (+, -, *, /): ")

if operator == "+":
    print("Result =", num1 + num2)

elif operator == "-":
    print("Result =", num1 - num2)

elif operator == "*":
    print("Result =", num1 * num2)

elif operator == "/":
    if num2 != 0:
        print("Result =", num1 / num2)
    else:
        print("Division by zero is not allowed")

else:
    print("Invalid operator")
# Out:
# Enter first number:  45
# Enter second number:  56
# Enter operator (+, -, *, /):  /
# Result = 0.8035714285714286
